# %%
import pandas as pd

# %% [markdown]
# # series using pandas

# %%
numbers = pd.Series([10, 20, 30, 40, 50])

numbers
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
marks = pd.Series(
    [85, 90, 78, 92],
    index=["Math", "Science", "English", "Computer"]
)

marks
# Out:
# Math        85
# Science     90
# English     78
# Computer    92
# dtype: int64

# %%
import pandas as pd

s = pd.Series(
    [99, 87, 98, 90, 46, 89, 76, 94],
    index=["Anish", "Rohan", "Aman", "Anshu", "Azmat", "Aaryan", "Ajit", "Sujit"],
    name="Marks"
)

print(s)
# Out:
# Anish     99
# Rohan     87
# Aman      98
# Anshu     90
# Azmat     46
# Aaryan    89
# Ajit      76
# Sujit     94
# Name: Marks, dtype: int64
