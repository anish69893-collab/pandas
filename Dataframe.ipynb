# %% [markdown]
# * DataFrame using in pandas

# %%
import pandas as pd

# %%
df=pd.DataFrame({"Name":["Anish","Manvi","Anshu","Aman",],
                 "subject":["Math","Python","data structures","Computer system Architecture",],
                 "Marks":[99,98,89,78,]})
print(df)
# Out:
#     Name                       subject  Marks
# 0  Anish                          Math     99
# 1  Manvi                        Python     98
# 2  Anshu               data structures     89
# 3   Aman  Computer system Architecture     78

# %%
import pandas as pd

df=pd.DataFrame({
    "Roll No": [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    "Name": ["Anish", "Rohan", "Aman", "Anshu", "Azmat",
             "Aaryan", "Ajit", "Sujit", "Rahul", "Neha"],
    "Course": ["CSE", "CSE", "MCA", "CSE", "BCA",
               "MCA", "CSE", "BCA", "CSE", "MCA"],
    "Marks": [99, 87, 98, 90, 46, 89, 76, 94, 85, 91]})



print(df)
# Out:
#    Roll No    Name Course  Marks
# 0      101   Anish    CSE     99
# 1      102   Rohan    CSE     87
# 2      103    Aman    MCA     98
# 3      104   Anshu    CSE     90
# 4      105   Azmat    BCA     46
# 5      106  Aaryan    MCA     89
# 6      107    Ajit    CSE     76
# 7      108   Sujit    BCA     94
# 8      109   Rahul    CSE     85
# 9      110    Neha    MCA     91

# %%
import pandas as pd

df = pd.DataFrame({
    "Name": ["Anish", "Rohan", "Aman", "Anshu"],
    "Marks": [99, 87, 98, 90]
})



print(df)
print("Total Marks:", df["Marks"].sum())
# Out:
#     Name  Marks
# 0  Anish     99
# 1  Rohan     87
# 2   Aman     98
# 3  Anshu     90
# Total Marks: 374

# %%
df1=pd.DataFrame({"Name":["Anish","Aman","Rohan","Ajit",],
                  "Marks":[99,98,76,54,]})
print(df1)
# Out:
#     Name  Marks
# 0  Anish     99
# 1   Aman     98
# 2  Rohan     76
# 3   Ajit     54

# %%
df2=pd.DataFrame({"Name":["Manvi","Roshani","Kajal","Anisha",],
                  "Marks":[99,78,65,34,]})
print(df2)
# Out:
#       Name  Marks
# 0    Manvi     99
# 1  Roshani     78
# 2    Kajal     65
# 3   Anisha     34

# %%
print(pd.concat([df1,df2]))
# Out:
#       Name  Marks
# 0    Anish     99
# 1     Aman     98
# 2    Rohan     76
# 3     Ajit     54
# 0    Manvi     99
# 1  Roshani     78
# 2    Kajal     65
# 3   Anisha     34

# %%
df1=pd.DataFrame({"Name":["Manvi","Roshani","Kajal","Anisha",],
                  "Marks":[99,78,65,34,]})
print(df1)
# Out:
#       Name  Marks
# 0    Manvi     99
# 1  Roshani     78
# 2    Kajal     65
# 3   Anisha     34

# %%
df2=pd.DataFrame({"Name":["Manvi","Roshani","Kajal","Anisha",],
                  "Roll no":[11,34,78,53]})
print(df2)
# Out:
#       Name  Roll no
# 0    Manvi       11
# 1  Roshani       34
# 2    Kajal       78
# 3   Anisha       53

# %%
print(pd.merge(df1,df2, on="Name"))
# Out:
#       Name  Marks  Roll no
# 0    Manvi     99       11
# 1  Roshani     78       34
# 2    Kajal     65       78
# 3   Anisha     34       53
